# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # load pre-trained model
results = model("C:/Users/ss/OneDrive/Pictures/d1.png")  # inference
results[0].show()  # display result
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:08<00:00, 760kB/s]
# image 1/1 C:\Users\ss\OneDrive\Pictures\d1.png: 416x640 12 persons, 3 cars, 1 motorcycle, 1 truck, 202.1ms
# Speed: 11.8ms preprocess, 202.1ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)

# %%
from ultralytics import YOLO
import cv2
from deep_sort_realtime.deepsort_tracker import DeepSort

# %%
# Load pre-trained YOLOv8 model (nano/small/medium/large/extra large)
model = YOLO("yolov8n.pt")  # or yolov8s.pt, etc.
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:08<00:00, 759kB/s]

# %%
tracker = DeepSort(max_age=25)  # You can tweak parameters

# %%
TARGET_CLASS = "person"  # Change to "car" or any class of interest

# %%
# Open video or webcam
cap = cv2.VideoCapture(0)  # Or use 0 for webcam
# r'C:\Users\ss\Downloads\honda.mp4

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 detection
    results = model(frame)[0]

    detections = []

    for box in results.boxes:
        cls_id = int(box.cls[0])
        class_name = model.names[cls_id]

        # Only track the specified class
        if class_name != TARGET_CLASS:
            continue
        conf = float(box.conf[0])
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        detections.append([[x1, y1, x2 - x1, y2 - y1], conf, class_name])

    # Update Deep SORT tracker
    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue
        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)

        # Draw bounding box & ID
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f"{TARGET_CLASS} ID:{track_id}", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    cv2.imshow("Tracking", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
import cv2
from deep_sort_realtime.deepsort_tracker import DeepSort


model = YOLO("yolov8n.pt")
tracker = DeepSort(max_age=25)
TARGET_CLASS = "person"
cap = cv2.VideoCapture(r'C:\Users\ss\Downloads\welcome.mp4')

while True:
    ret, frame = cap.read()

    if not ret:
        break

    results = model(frame)[0]
    detections = []
    for box in results.boxes:
        cls_id = int(box.cls[0])
        class_name = model.names[cls_id]
        if class_name == TARGET_CLASS:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = float(box.conf[0])
            detections.append(([x1, y1, x2 - x1, y2 - y1],conf, "person"))

    tracks = tracker.update_tracks(detections, frame=frame)
    for track in tracks:
        if not track.is_confirmed():
            continue
        x1, y1, x2, y2 = map(int, track.to_ltrb())
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f'ID {track.track_id}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
    cv2.imshow("Tracking", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 (no detections), 425.6ms
# Speed: 23.5ms preprocess, 425.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 persons, 1 surfboard, 279.0ms
# Speed: 28.8ms preprocess, 279.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 persons, 1 surfboard, 154.1ms
# Speed: 4.0ms preprocess, 154.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 persons, 1 skateboard, 1 surfboard, 156.8ms
# Speed: 6.9ms preprocess, 156.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 surfboard, 197.5ms
# Speed: 5.1ms preprocess, 197.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 persons, 1 surfboard, 187.5ms
# Speed: 5.9ms preprocess, 187.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 1 surfboard, 221.4ms
# Speed: 6.7ms preprocess, 221.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 persons, 1 surfboard, 238.2ms
# Speed: 7.2ms preprocess, 238.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# # Beginner-Friendly YOLO Object Detection
#
# This section contains simplified code that's easier to understand for beginners. We'll break down the process into smaller, manageable steps.

# %%
# Step 1: Simple Image Detection (Beginner Version)
from ultralytics import YOLO
import cv2

# Load the YOLO model
print("Loading YOLO model...")
model = YOLO("yolov8n.pt")

# Load an image
image_path = "C:/Users/ss/OneDrive/Pictures/d1.png"  # Change this to your image path
print(f"Loading image: {image_path}")

try:
    # Read the image
    image = cv2.imread(image_path)
    
    if image is None:
        print("Error: Could not load image. Please check the file path.")
    else:
        print("Image loaded successfully!")
        
        # Run detection
        print("Running object detection...")
        results = model(image)
        
        # Show results with bounding boxes
        annotated_image = results[0].plot()
        
        # Display the image
        cv2.imshow("YOLO Detection Results", annotated_image)
        cv2.waitKey(0)  # Wait for a key press
        cv2.destroyAllWindows()
        
        # Print detected objects
        print("\nDetected objects:")
        for i, box in enumerate(results[0].boxes):
            class_id = int(box.cls[0])
            class_name = results[0].names[class_id]
            confidence = float(box.conf[0])
            print(f"{i+1}. {class_name} (confidence: {confidence:.2f})")
            
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Step 2: Simple Webcam Detection (Beginner Version)
from ultralytics import YOLO
import cv2

# Load the YOLO model
model = YOLO("yolov8n.pt")

print("Starting webcam detection...")
print("Press 'q' to quit")

# Open webcam (0 is usually the default camera)
cap = cv2.VideoCapture( 0)

# Check if webcam opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam")
else:
    while True:
        # Read frame from webcam
        ret, frame = cap.read()
        
        if not ret:
            print("Error: Could not read frame")
            break
        
        # Run YOLO detection on the frame
        results = model(frame)
        
        # Draw the detection results on the frame
        annotated_frame = results[0].plot()
        
        # Display the frame
        cv2.imshow("Webcam YOLO Detection", annotated_frame)
        
        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # Clean up
    cap.release()
    cv2.destroyAllWindows()
    print("Webcam detection ended.")
# Out:
# Starting webcam detection...
# Press 'q' to quit
#
#
# 0: 640x384 1 person, 324.2ms
# Speed: 5.5ms preprocess, 324.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 324.2ms
# Speed: 5.5ms preprocess, 324.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 196.2ms
# Speed: 20.2ms preprocess, 196.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 196.2ms
# Speed: 20.2ms preprocess, 196.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 147.5ms
# Speed: 2.6ms preprocess, 147.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 147.5ms
# Speed: 2.6ms preprocess, 147.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 142.8ms
# Speed: 2.5ms preprocess, 142.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 142.8ms
# Speed: 2.5ms preprocess, 142.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 150.5ms
# Speed: 4.7ms preprocess, 150.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 150.5ms
# Speed: 4.7ms preprocess, 150.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.1ms
# Speed: 5.9ms preprocess, 138.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 138.1ms
# Speed: 5.9ms preprocess, 138.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 169.8ms
# Speed: 6.8ms preprocess, 169.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.8ms
# Speed: 6.8ms preprocess, 169.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 143.3ms
# Speed: 2.5ms preprocess, 143.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 143.3ms
# Speed: 2.5ms preprocess, 143.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 140.5ms
# Speed: 3.4ms preprocess, 140.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 140.5ms
# Speed: 3.4ms preprocess, 140.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 135.4ms
# Speed: 3.2ms preprocess, 135.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 135.4ms
# Speed: 3.2ms preprocess, 135.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 145.0ms
# Speed: 2.2ms preprocess, 145.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 145.0ms
# Speed: 2.2ms preprocess, 145.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 146.6ms
# Speed: 4.3ms preprocess, 146.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 146.6ms
# Speed: 4.3ms preprocess, 146.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 160.0ms
# Speed: 3.7ms preprocess, 160.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.0ms
# Speed: 3.7ms preprocess, 160.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.4ms
# Speed: 2.5ms preprocess, 153.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.4ms
# Speed: 2.5ms preprocess, 153.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.6ms
# Speed: 5.1ms preprocess, 154.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.6ms
# Speed: 5.1ms preprocess, 154.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.7ms
# Speed: 2.7ms preprocess, 153.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 153.7ms
# Speed: 2.7ms preprocess, 153.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 153.7ms
# Speed: 5.9ms preprocess, 153.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.7ms
# Speed: 5.9ms preprocess, 153.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 148.0ms
# Speed: 2.7ms preprocess, 148.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 148.0ms
# Speed: 2.7ms preprocess, 148.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 refrigerator, 142.8ms
# Speed: 2.6ms preprocess, 142.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 refrigerator, 142.8ms
# Speed: 2.6ms preprocess, 142.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 refrigerator, 161.3ms
# Speed: 2.3ms preprocess, 161.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 refrigerator, 161.3ms
# Speed: 2.3ms preprocess, 161.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 148.1ms
# Speed: 4.6ms preprocess, 148.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 148.1ms
# Speed: 4.6ms preprocess, 148.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 banana, 136.4ms
# Speed: 6.1ms preprocess, 136.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 136.4ms
# Speed: 6.1ms preprocess, 136.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 1 refrigerator, 136.3ms
# Speed: 3.2ms preprocess, 136.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 1 refrigerator, 136.3ms
# Speed: 3.2ms preprocess, 136.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 1 refrigerator, 134.1ms
# Speed: 2.7ms preprocess, 134.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 banana, 1 refrigerator, 134.1ms
# Speed: 2.7ms preprocess, 134.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 refrigerator, 135.8ms
# Speed: 3.1ms preprocess, 135.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 refrigerator, 135.8ms
# Speed: 3.1ms preprocess, 135.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 135.5ms
# Speed: 4.9ms preprocess, 135.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 135.5ms
# Speed: 4.9ms preprocess, 135.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 135.5ms
# Speed: 2.8ms preprocess, 135.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 banana, 135.5ms
# Speed: 2.8ms preprocess, 135.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 banana, 140.6ms
# Speed: 3.2ms preprocess, 140.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 banana, 140.6ms
# Speed: 3.2ms preprocess, 140.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 138.0ms
# Speed: 3.8ms preprocess, 138.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.0ms
# Speed: 3.8ms preprocess, 138.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 137.6ms
# Speed: 2.6ms preprocess, 137.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 137.6ms
# Speed: 2.6ms preprocess, 137.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 132.1ms
# Speed: 2.8ms preprocess, 132.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 banana, 132.1ms
# Speed: 2.8ms preprocess, 132.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 139.6ms
# Speed: 3.2ms preprocess, 139.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 139.6ms
# Speed: 3.2ms preprocess, 139.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.1ms
# Speed: 2.8ms preprocess, 136.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.1ms
# Speed: 2.8ms preprocess, 136.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 refrigerator, 134.7ms
# Speed: 3.3ms preprocess, 134.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 refrigerator, 134.7ms
# Speed: 3.3ms preprocess, 134.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 1 refrigerator, 142.2ms
# Speed: 3.0ms preprocess, 142.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 1 refrigerator, 142.2ms
# Speed: 3.0ms preprocess, 142.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 138.4ms
# Speed: 3.1ms preprocess, 138.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 banana, 138.4ms
# Speed: 3.1ms preprocess, 138.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 139.5ms
# Speed: 3.1ms preprocess, 139.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 139.5ms
# Speed: 3.1ms preprocess, 139.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 139.4ms
# Speed: 3.6ms preprocess, 139.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 139.4ms
# Speed: 3.6ms preprocess, 139.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.5ms
# Speed: 4.1ms preprocess, 136.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.5ms
# Speed: 4.1ms preprocess, 136.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 132.6ms
# Speed: 2.7ms preprocess, 132.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 132.6ms
# Speed: 2.7ms preprocess, 132.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 138.4ms
# Speed: 4.2ms preprocess, 138.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 138.4ms
# Speed: 4.2ms preprocess, 138.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 139.3ms
# Speed: 3.4ms preprocess, 139.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 139.3ms
# Speed: 3.4ms preprocess, 139.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 142.8ms
# Speed: 2.5ms preprocess, 142.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 142.8ms
# Speed: 2.5ms preprocess, 142.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 145.1ms
# Speed: 5.5ms preprocess, 145.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 145.1ms
# Speed: 5.5ms preprocess, 145.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 6.4ms preprocess, 158.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 6.4ms preprocess, 158.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 refrigerator, 142.4ms
# Speed: 2.5ms preprocess, 142.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 refrigerator, 142.4ms
# Speed: 2.5ms preprocess, 142.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 refrigerator, 145.8ms
# Speed: 4.4ms preprocess, 145.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 refrigerator, 145.8ms
# Speed: 4.4ms preprocess, 145.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 140.5ms
# Speed: 2.6ms preprocess, 140.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 140.5ms
# Speed: 2.6ms preprocess, 140.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 267.6ms
# Speed: 2.9ms preprocess, 267.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 267.6ms
# Speed: 2.9ms preprocess, 267.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 146.4ms
# Speed: 2.6ms preprocess, 146.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 146.4ms
# Speed: 2.6ms preprocess, 146.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 136.1ms
# Speed: 3.3ms preprocess, 136.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.1ms
# Speed: 3.3ms preprocess, 136.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 140.9ms
# Speed: 2.8ms preprocess, 140.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 140.9ms
# Speed: 2.8ms preprocess, 140.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 136.3ms
# Speed: 3.7ms preprocess, 136.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.3ms
# Speed: 3.7ms preprocess, 136.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.0ms
# Speed: 2.7ms preprocess, 138.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.0ms
# Speed: 2.7ms preprocess, 138.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 135.5ms
# Speed: 3.1ms preprocess, 135.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 banana, 135.5ms
# Speed: 3.1ms preprocess, 135.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 banana, 137.6ms
# Speed: 3.3ms preprocess, 137.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 137.6ms
# Speed: 3.3ms preprocess, 137.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 140.1ms
# Speed: 2.5ms preprocess, 140.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 140.1ms
# Speed: 2.5ms preprocess, 140.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 137.8ms
# Speed: 2.6ms preprocess, 137.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 137.8ms
# Speed: 2.6ms preprocess, 137.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 144.0ms
# Speed: 3.0ms preprocess, 144.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 144.0ms
# Speed: 3.0ms preprocess, 144.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 144.8ms
# Speed: 3.4ms preprocess, 144.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 144.8ms
# Speed: 3.4ms preprocess, 144.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 banana, 139.7ms
# Speed: 3.5ms preprocess, 139.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 banana, 139.7ms
# Speed: 3.5ms preprocess, 139.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 banana, 134.5ms
# Speed: 5.7ms preprocess, 134.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 banana, 134.5ms
# Speed: 5.7ms preprocess, 134.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 134.2ms
# Speed: 2.9ms preprocess, 134.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 134.2ms
# Speed: 2.9ms preprocess, 134.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 134.0ms
# Speed: 3.3ms preprocess, 134.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 134.0ms
# Speed: 3.3ms preprocess, 134.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 141.4ms
# Speed: 3.0ms preprocess, 141.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 141.4ms
# Speed: 3.0ms preprocess, 141.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 134.8ms
# Speed: 5.7ms preprocess, 134.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 134.8ms
# Speed: 5.7ms preprocess, 134.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.9ms
# Speed: 2.8ms preprocess, 136.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.9ms
# Speed: 2.8ms preprocess, 136.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 137.8ms
# Speed: 2.5ms preprocess, 137.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 137.8ms
# Speed: 2.5ms preprocess, 137.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.6ms
# Speed: 2.6ms preprocess, 138.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 138.6ms
# Speed: 2.6ms preprocess, 138.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 137.9ms
# Speed: 3.7ms preprocess, 137.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 137.9ms
# Speed: 3.7ms preprocess, 137.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 138.8ms
# Speed: 4.2ms preprocess, 138.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.8ms
# Speed: 4.2ms preprocess, 138.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 139.7ms
# Speed: 2.7ms preprocess, 139.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 139.7ms
# Speed: 2.7ms preprocess, 139.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 137.0ms
# Speed: 5.3ms preprocess, 137.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 137.0ms
# Speed: 5.3ms preprocess, 137.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.4ms
# Speed: 2.8ms preprocess, 136.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.4ms
# Speed: 2.8ms preprocess, 136.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 139.2ms
# Speed: 2.8ms preprocess, 139.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 139.2ms
# Speed: 2.8ms preprocess, 139.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 138.6ms
# Speed: 3.7ms preprocess, 138.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.6ms
# Speed: 3.7ms preprocess, 138.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.0ms
# Speed: 4.1ms preprocess, 136.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 136.0ms
# Speed: 4.1ms preprocess, 136.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 138.5ms
# Speed: 3.7ms preprocess, 138.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.5ms
# Speed: 3.7ms preprocess, 138.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.2ms
# Speed: 4.4ms preprocess, 138.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 138.2ms
# Speed: 4.4ms preprocess, 138.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 134.6ms
# Speed: 3.3ms preprocess, 134.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 2 persons, 134.6ms
# Speed: 3.3ms preprocess, 134.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 4 persons, 138.8ms
# Speed: 3.3ms preprocess, 138.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 138.8ms
# Speed: 3.3ms preprocess, 138.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 140.9ms
# Speed: 3.7ms preprocess, 140.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 motorcycle, 140.9ms
# Speed: 3.7ms preprocess, 140.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 motorcycle, 135.6ms
# Speed: 2.7ms preprocess, 135.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 135.6ms
# Speed: 2.7ms preprocess, 135.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.7ms
# Speed: 2.7ms preprocess, 136.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 136.7ms
# Speed: 2.7ms preprocess, 136.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 141.9ms
# Speed: 2.7ms preprocess, 141.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 person, 1 motorcycle, 141.9ms
# Speed: 2.7ms preprocess, 141.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 2 persons, 1 car, 1 motorcycle, 139.6ms
# Speed: 3.5ms preprocess, 139.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 2 persons, 1 car, 1 motorcycle, 139.6ms
# Speed: 3.5ms preprocess, 139.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 138.1ms
# Speed: 3.3ms preprocess, 138.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 138.1ms
# Speed: 3.3ms preprocess, 138.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 138.6ms
# Speed: 2.7ms preprocess, 138.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 138.6ms
# Speed: 2.7ms preprocess, 138.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 134.6ms
# Speed: 3.0ms preprocess, 134.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 car, 1 motorcycle, 134.6ms
# Speed: 3.0ms preprocess, 134.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 car, 1 motorcycle, 143.6ms
# Speed: 4.1ms preprocess, 143.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 1 motorcycle, 143.6ms
# Speed: 4.1ms preprocess, 143.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 136.3ms
# Speed: 3.0ms preprocess, 136.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 136.3ms
# Speed: 3.0ms preprocess, 136.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 1 motorcycle, 1 airplane, 141.0ms
# Speed: 3.4ms preprocess, 141.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 2 persons, 1 car, 1 motorcycle, 1 airplane, 141.0ms
# Speed: 3.4ms preprocess, 141.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 139.1ms
# Speed: 3.8ms preprocess, 139.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 139.1ms
# Speed: 3.8ms preprocess, 139.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 136.0ms
# Speed: 2.9ms preprocess, 136.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 motorcycle, 1 airplane, 136.0ms
# Speed: 2.9ms preprocess, 136.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 153.6ms
# Speed: 2.8ms preprocess, 153.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 motorcycle, 1 airplane, 153.6ms
# Speed: 2.8ms preprocess, 153.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 motorcycle, 1 airplane, 139.8ms
# Speed: 3.8ms preprocess, 139.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 139.8ms
# Speed: 3.8ms preprocess, 139.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 262.9ms
# Speed: 2.8ms preprocess, 262.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 262.9ms
# Speed: 2.8ms preprocess, 262.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 138.1ms
# Speed: 2.5ms preprocess, 138.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 motorcycle, 1 airplane, 138.1ms
# Speed: 2.5ms preprocess, 138.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 motorcycle, 1 airplane, 138.7ms
# Speed: 3.7ms preprocess, 138.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 motorcycle, 1 airplane, 138.7ms
# Speed: 3.7ms preprocess, 138.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 motorcycle, 1 airplane, 136.0ms
# Speed: 3.3ms preprocess, 136.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 136.0ms
# Speed: 3.3ms preprocess, 136.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 135.5ms
# Speed: 3.1ms preprocess, 135.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 135.5ms
# Speed: 3.1ms preprocess, 135.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 134.1ms
# Speed: 6.3ms preprocess, 134.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 134.1ms
# Speed: 6.3ms preprocess, 134.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 136.2ms
# Speed: 3.0ms preprocess, 136.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 136.2ms
# Speed: 3.0ms preprocess, 136.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 137.4ms
# Speed: 2.3ms preprocess, 137.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 motorcycle, 1 airplane, 137.4ms
# Speed: 2.3ms preprocess, 137.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 motorcycle, 1 airplane, 138.4ms
# Speed: 3.3ms preprocess, 138.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 motorcycle, 1 airplane, 138.4ms
# Speed: 3.3ms preprocess, 138.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 airplane, 140.9ms
# Speed: 3.6ms preprocess, 140.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 airplane, 140.9ms
# Speed: 3.6ms preprocess, 140.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 airplane, 137.6ms
# Speed: 2.5ms preprocess, 137.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 airplane, 137.6ms
# Speed: 2.5ms preprocess, 137.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 airplane, 143.2ms
# Speed: 3.0ms preprocess, 143.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 airplane, 143.2ms
# Speed: 3.0ms preprocess, 143.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
#
# 0: 640x384 1 airplane, 136.3ms
# Speed: 4.4ms preprocess, 136.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 0: 640x384 1 airplane, 136.3ms
# Speed: 4.4ms preprocess, 136.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Webcam detection ended.
# Webcam detection ended.

# %%
# Step 3: Count Specific Objects (Beginner Version)
from ultralytics import YOLO
import cv2

# Load the YOLO model
model = YOLO("yolov8n.pt")

# What object do you want to count?
target_object = "person"  # Change this to "car", "dog", "cat", etc.

print(f"Starting webcam detection to count: {target_object}")
print("Press 'q' to quit")

# Open webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam")
else:
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break
        
        # Run detection
        results = model(frame)
        
        # Count the target objects
        count = 0
        
        # Loop through all detected objects
        for box in results[0].boxes:
            class_id = int(box.cls[0])
            class_name = results[0].names[class_id]
            confidence = float(box.conf[0])
            
            # If it's our target object and confidence is high enough
            if class_name == target_object and confidence > 0.5:
                count += 1
                
                # Draw bounding box for target objects only
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, f"{class_name} {confidence:.2f}", 
                           (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        
        # Display the count on screen
        cv2.putText(frame, f"{target_object} count: {count}", 
                   (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        
        # Show the frame
        cv2.imshow(f"Counting {target_object}", frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    cv2.destroyAllWindows()
    print("Object counting ended.")
# Out:
# Starting webcam detection to count: person
# Press 'q' to quit
#
#
# 0: 480x640 (no detections), 522.2ms
# Speed: 47.5ms preprocess, 522.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 522.2ms
# Speed: 47.5ms preprocess, 522.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 222.4ms
# Speed: 7.7ms preprocess, 222.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.4ms
# Speed: 7.7ms preprocess, 222.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.6ms
# Speed: 6.5ms preprocess, 170.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 2 persons, 170.6ms
# Speed: 6.5ms preprocess, 170.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 180.7ms
# Speed: 3.2ms preprocess, 180.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.7ms
# Speed: 3.2ms preprocess, 180.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.0ms
# Speed: 4.0ms preprocess, 172.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.0ms
# Speed: 4.0ms preprocess, 172.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 180.5ms
# Speed: 4.2ms preprocess, 180.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 180.5ms
# Speed: 4.2ms preprocess, 180.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.5ms
# Speed: 3.3ms preprocess, 167.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.5ms
# Speed: 3.3ms preprocess, 167.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 162.8ms
# Speed: 3.1ms preprocess, 162.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 162.8ms
# Speed: 3.1ms preprocess, 162.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.4ms
# Speed: 5.0ms preprocess, 165.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 165.4ms
# Speed: 5.0ms preprocess, 165.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 2 persons, 169.4ms
# Speed: 3.6ms preprocess, 169.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 169.4ms
# Speed: 3.6ms preprocess, 169.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.2ms
# Speed: 3.9ms preprocess, 165.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.2ms
# Speed: 3.9ms preprocess, 165.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 294.4ms
# Speed: 3.8ms preprocess, 294.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 294.4ms
# Speed: 3.8ms preprocess, 294.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.7ms
# Speed: 2.5ms preprocess, 160.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.7ms
# Speed: 2.5ms preprocess, 160.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 175.9ms
# Speed: 2.9ms preprocess, 175.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 175.9ms
# Speed: 2.9ms preprocess, 175.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.2ms
# Speed: 3.1ms preprocess, 167.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.2ms
# Speed: 3.1ms preprocess, 167.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 165.3ms
# Speed: 5.6ms preprocess, 165.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 165.3ms
# Speed: 5.6ms preprocess, 165.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.0ms
# Speed: 3.0ms preprocess, 170.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.0ms
# Speed: 3.0ms preprocess, 170.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.2ms
# Speed: 6.5ms preprocess, 162.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.2ms
# Speed: 6.5ms preprocess, 162.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.9ms
# Speed: 3.0ms preprocess, 163.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 2 persons, 163.9ms
# Speed: 3.0ms preprocess, 163.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 168.9ms
# Speed: 3.1ms preprocess, 168.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.9ms
# Speed: 3.1ms preprocess, 168.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.4ms
# Speed: 3.0ms preprocess, 165.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.4ms
# Speed: 3.0ms preprocess, 165.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 191.7ms
# Speed: 2.9ms preprocess, 191.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 191.7ms
# Speed: 2.9ms preprocess, 191.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.1ms
# Speed: 4.1ms preprocess, 175.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.1ms
# Speed: 4.1ms preprocess, 175.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.9ms
# Speed: 3.4ms preprocess, 164.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.9ms
# Speed: 3.4ms preprocess, 164.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.0ms
# Speed: 4.8ms preprocess, 163.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.0ms
# Speed: 4.8ms preprocess, 163.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.0ms
# Speed: 3.2ms preprocess, 163.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.0ms
# Speed: 3.2ms preprocess, 163.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 189.2ms
# Speed: 3.5ms preprocess, 189.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 189.2ms
# Speed: 3.5ms preprocess, 189.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.7ms
# Speed: 2.7ms preprocess, 163.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 163.7ms
# Speed: 2.7ms preprocess, 163.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 169.2ms
# Speed: 3.9ms preprocess, 169.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.2ms
# Speed: 3.9ms preprocess, 169.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 160.5ms
# Speed: 3.6ms preprocess, 160.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 160.5ms
# Speed: 3.6ms preprocess, 160.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 150.0ms
# Speed: 3.6ms preprocess, 150.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 150.0ms
# Speed: 3.6ms preprocess, 150.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.8ms
# Speed: 2.8ms preprocess, 144.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.8ms
# Speed: 2.8ms preprocess, 144.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.6ms
# Speed: 2.9ms preprocess, 144.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.6ms
# Speed: 2.9ms preprocess, 144.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 155.2ms
# Speed: 2.8ms preprocess, 155.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 155.2ms
# Speed: 2.8ms preprocess, 155.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 173.3ms
# Speed: 6.7ms preprocess, 173.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.3ms
# Speed: 6.7ms preprocess, 173.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dog, 164.8ms
# Speed: 3.9ms preprocess, 164.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dog, 164.8ms
# Speed: 3.9ms preprocess, 164.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.6ms
# Speed: 5.2ms preprocess, 164.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.6ms
# Speed: 5.2ms preprocess, 164.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.0ms
# Speed: 3.9ms preprocess, 167.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.0ms
# Speed: 3.9ms preprocess, 167.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.1ms
# Speed: 3.2ms preprocess, 170.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.1ms
# Speed: 3.2ms preprocess, 170.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.8ms
# Speed: 2.5ms preprocess, 166.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.8ms
# Speed: 2.5ms preprocess, 166.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 168.8ms
# Speed: 3.4ms preprocess, 168.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 2 persons, 168.8ms
# Speed: 3.4ms preprocess, 168.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 168.2ms
# Speed: 3.4ms preprocess, 168.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.2ms
# Speed: 3.4ms preprocess, 168.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.2ms
# Speed: 9.5ms preprocess, 164.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.2ms
# Speed: 9.5ms preprocess, 164.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 305.8ms
# Speed: 4.0ms preprocess, 305.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 305.8ms
# Speed: 4.0ms preprocess, 305.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 2 persons, 170.4ms
# Speed: 4.4ms preprocess, 170.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.4ms
# Speed: 4.4ms preprocess, 170.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.0ms
# Speed: 3.7ms preprocess, 164.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.0ms
# Speed: 3.7ms preprocess, 164.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.3ms
# Speed: 2.4ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.3ms
# Speed: 2.4ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.1ms
# Speed: 6.0ms preprocess, 164.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.1ms
# Speed: 6.0ms preprocess, 164.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.4ms
# Speed: 3.4ms preprocess, 168.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.4ms
# Speed: 3.4ms preprocess, 168.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.9ms
# Speed: 3.0ms preprocess, 163.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.9ms
# Speed: 3.0ms preprocess, 163.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.6ms
# Speed: 5.4ms preprocess, 164.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.6ms
# Speed: 5.4ms preprocess, 164.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.6ms
# Speed: 4.3ms preprocess, 162.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 162.6ms
# Speed: 4.3ms preprocess, 162.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 169.9ms
# Speed: 3.3ms preprocess, 169.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.9ms
# Speed: 3.3ms preprocess, 169.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.3ms
# Speed: 2.5ms preprocess, 167.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.3ms
# Speed: 2.5ms preprocess, 167.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 165.3ms
# Speed: 2.9ms preprocess, 165.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 cat, 165.3ms
# Speed: 2.9ms preprocess, 165.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 cat, 163.9ms
# Speed: 4.8ms preprocess, 163.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 163.9ms
# Speed: 4.8ms preprocess, 163.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 162.5ms
# Speed: 2.4ms preprocess, 162.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 162.5ms
# Speed: 2.4ms preprocess, 162.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.1ms
# Speed: 2.4ms preprocess, 161.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.1ms
# Speed: 2.4ms preprocess, 161.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.7ms
# Speed: 3.6ms preprocess, 163.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.7ms
# Speed: 3.6ms preprocess, 163.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.5ms
# Speed: 2.5ms preprocess, 163.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.5ms
# Speed: 2.5ms preprocess, 163.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.7ms
# Speed: 2.9ms preprocess, 168.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.7ms
# Speed: 2.9ms preprocess, 168.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 158.0ms
# Speed: 3.7ms preprocess, 158.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 158.0ms
# Speed: 3.7ms preprocess, 158.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 161.7ms
# Speed: 3.6ms preprocess, 161.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 161.7ms
# Speed: 3.6ms preprocess, 161.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.3ms
# Speed: 7.2ms preprocess, 164.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.3ms
# Speed: 7.2ms preprocess, 164.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.0ms
# Speed: 4.0ms preprocess, 167.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 167.0ms
# Speed: 4.0ms preprocess, 167.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 163.6ms
# Speed: 4.1ms preprocess, 163.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 163.6ms
# Speed: 4.1ms preprocess, 163.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 165.3ms
# Speed: 4.0ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.3ms
# Speed: 4.0ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.2ms
# Speed: 3.5ms preprocess, 160.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.2ms
# Speed: 3.5ms preprocess, 160.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 161.2ms
# Speed: 2.9ms preprocess, 161.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 161.2ms
# Speed: 2.9ms preprocess, 161.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.2ms
# Speed: 5.7ms preprocess, 161.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 161.2ms
# Speed: 5.7ms preprocess, 161.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 167.8ms
# Speed: 7.1ms preprocess, 167.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.8ms
# Speed: 7.1ms preprocess, 167.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.9ms
# Speed: 4.1ms preprocess, 169.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.9ms
# Speed: 4.1ms preprocess, 169.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.4ms
# Speed: 2.9ms preprocess, 159.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 159.4ms
# Speed: 2.9ms preprocess, 159.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 164.7ms
# Speed: 3.4ms preprocess, 164.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.7ms
# Speed: 3.4ms preprocess, 164.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.0ms
# Speed: 2.5ms preprocess, 160.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 160.0ms
# Speed: 2.5ms preprocess, 160.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 166.4ms
# Speed: 3.9ms preprocess, 166.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.4ms
# Speed: 3.9ms preprocess, 166.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.5ms
# Speed: 3.3ms preprocess, 156.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.5ms
# Speed: 3.3ms preprocess, 156.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.4ms
# Speed: 2.8ms preprocess, 164.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.4ms
# Speed: 2.8ms preprocess, 164.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.4ms
# Speed: 3.0ms preprocess, 164.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.4ms
# Speed: 3.0ms preprocess, 164.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 dog, 162.1ms
# Speed: 3.0ms preprocess, 162.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 dog, 162.1ms
# Speed: 3.0ms preprocess, 162.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.8ms
# Speed: 2.9ms preprocess, 166.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.8ms
# Speed: 2.9ms preprocess, 166.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 158.9ms
# Speed: 8.1ms preprocess, 158.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 158.9ms
# Speed: 8.1ms preprocess, 158.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.0ms
# Speed: 3.2ms preprocess, 162.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 162.0ms
# Speed: 3.2ms preprocess, 162.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 166.0ms
# Speed: 3.7ms preprocess, 166.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 166.0ms
# Speed: 3.7ms preprocess, 166.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 181.2ms
# Speed: 3.2ms preprocess, 181.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.2ms
# Speed: 3.2ms preprocess, 181.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 164.2ms
# Speed: 2.7ms preprocess, 164.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 164.2ms
# Speed: 2.7ms preprocess, 164.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 167.5ms
# Speed: 3.9ms preprocess, 167.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 167.5ms
# Speed: 3.9ms preprocess, 167.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bird, 159.2ms
# Speed: 3.5ms preprocess, 159.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1 bird, 159.2ms
# Speed: 3.5ms preprocess, 159.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 1 bird, 164.6ms
# Speed: 5.4ms preprocess, 164.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bird, 164.6ms
# Speed: 5.4ms preprocess, 164.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.7ms
# Speed: 4.1ms preprocess, 164.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 164.7ms
# Speed: 4.1ms preprocess, 164.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 168.9ms
# Speed: 3.8ms preprocess, 168.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.9ms
# Speed: 3.8ms preprocess, 168.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.9ms
# Speed: 2.5ms preprocess, 166.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.9ms
# Speed: 2.5ms preprocess, 166.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 frisbee, 161.4ms
# Speed: 3.9ms preprocess, 161.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 frisbee, 161.4ms
# Speed: 3.9ms preprocess, 161.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.8ms
# Speed: 2.9ms preprocess, 161.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.8ms
# Speed: 2.9ms preprocess, 161.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 154.5ms
# Speed: 3.4ms preprocess, 154.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 154.5ms
# Speed: 3.4ms preprocess, 154.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 289.2ms
# Speed: 4.6ms preprocess, 289.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 289.2ms
# Speed: 4.6ms preprocess, 289.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.6ms
# Speed: 3.0ms preprocess, 172.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.6ms
# Speed: 3.0ms preprocess, 172.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.2ms
# Speed: 3.3ms preprocess, 165.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.2ms
# Speed: 3.3ms preprocess, 165.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 165.6ms
# Speed: 3.0ms preprocess, 165.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 (no detections), 165.6ms
# Speed: 3.0ms preprocess, 165.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 166.8ms
# Speed: 3.2ms preprocess, 166.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.8ms
# Speed: 3.2ms preprocess, 166.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 159.9ms
# Speed: 2.9ms preprocess, 159.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 159.9ms
# Speed: 2.9ms preprocess, 159.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.9ms
# Speed: 3.0ms preprocess, 165.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.9ms
# Speed: 3.0ms preprocess, 165.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.5ms
# Speed: 7.7ms preprocess, 159.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 159.5ms
# Speed: 7.7ms preprocess, 159.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 1 bed, 169.3ms
# Speed: 4.9ms preprocess, 169.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 169.3ms
# Speed: 4.9ms preprocess, 169.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.4ms
# Speed: 2.8ms preprocess, 167.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.4ms
# Speed: 2.8ms preprocess, 167.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.3ms
# Speed: 2.5ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.3ms
# Speed: 2.5ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.3ms
# Speed: 2.9ms preprocess, 163.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.3ms
# Speed: 2.9ms preprocess, 163.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.4ms
# Speed: 2.3ms preprocess, 163.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.4ms
# Speed: 2.3ms preprocess, 163.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 162.3ms
# Speed: 2.5ms preprocess, 162.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 162.3ms
# Speed: 2.5ms preprocess, 162.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.8ms
# Speed: 3.8ms preprocess, 165.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 2 persons, 165.8ms
# Speed: 3.8ms preprocess, 165.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 2 persons, 166.7ms
# Speed: 4.9ms preprocess, 166.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.7ms
# Speed: 4.9ms preprocess, 166.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 154.0ms
# Speed: 5.7ms preprocess, 154.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 154.0ms
# Speed: 5.7ms preprocess, 154.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 174.8ms
# Speed: 3.0ms preprocess, 174.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 174.8ms
# Speed: 3.0ms preprocess, 174.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.3ms
# Speed: 4.5ms preprocess, 157.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.3ms
# Speed: 4.5ms preprocess, 157.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.0ms
# Speed: 2.7ms preprocess, 160.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 160.0ms
# Speed: 2.7ms preprocess, 160.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 1 person, 162.7ms
# Speed: 3.3ms preprocess, 162.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.7ms
# Speed: 3.3ms preprocess, 162.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.3ms
# Speed: 2.9ms preprocess, 165.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.3ms
# Speed: 2.9ms preprocess, 165.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 162.3ms
# Speed: 2.9ms preprocess, 162.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 2 persons, 162.3ms
# Speed: 2.9ms preprocess, 162.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 2 persons, 171.8ms
# Speed: 3.2ms preprocess, 171.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.8ms
# Speed: 3.2ms preprocess, 171.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.4ms
# Speed: 4.1ms preprocess, 162.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.4ms
# Speed: 4.1ms preprocess, 162.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.6ms
# Speed: 4.2ms preprocess, 159.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.6ms
# Speed: 4.2ms preprocess, 159.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.0ms
# Speed: 3.6ms preprocess, 164.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 2 persons, 164.0ms
# Speed: 3.6ms preprocess, 164.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
#
# 0: 480x640 2 persons, 169.3ms
# Speed: 3.6ms preprocess, 169.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 169.3ms
# Speed: 3.6ms preprocess, 169.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.0ms
# Speed: 3.4ms preprocess, 164.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.0ms
# Speed: 3.4ms preprocess, 164.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.4ms
# Speed: 2.5ms preprocess, 166.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.4ms
# Speed: 2.5ms preprocess, 166.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bed, 161.9ms
# Speed: 2.4ms preprocess, 161.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bed, 161.9ms
# Speed: 2.4ms preprocess, 161.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.8ms
# Speed: 3.3ms preprocess, 165.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.8ms
# Speed: 3.3ms preprocess, 165.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.3ms
# Speed: 3.1ms preprocess, 156.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.3ms
# Speed: 3.1ms preprocess, 156.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.5ms
# Speed: 2.9ms preprocess, 166.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.5ms
# Speed: 2.9ms preprocess, 166.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.7ms
# Speed: 2.9ms preprocess, 167.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.7ms
# Speed: 2.9ms preprocess, 167.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.3ms
# Speed: 3.0ms preprocess, 163.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.3ms
# Speed: 3.0ms preprocess, 163.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 161.1ms
# Speed: 2.9ms preprocess, 161.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 161.1ms
# Speed: 2.9ms preprocess, 161.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.3ms
# Speed: 2.9ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 165.3ms
# Speed: 2.9ms preprocess, 165.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Object counting ended.
# Object counting ended.

# %%
# Step 4: Process Video File (Beginner Version)
from ultralytics import YOLO
import cv2

# Load the YOLO model
model = YOLO("yolov8n.pt")

# Video file path (change this to your video file)
video_path = "C:/Users/ss/Downloads/honda.mp4"  # Update with your video path

print(f"Processing video: {video_path}")
print("Press 'q' to quit early")

# Open video file
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Could not open video file")
    print("Make sure the file path is correct and the video format is supported")
else:
    # Get video properties
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    print(f"Video info: {total_frames} frames, {fps:.2f} FPS")
    
    frame_count = 0
    
    while True:
        ret, frame = cap.read()
        
        if not ret:
            print("End of video reached")
            break
        
        frame_count += 1
        
        # Process every 5th frame to speed up (optional)
        if frame_count % 5 == 0:
            # Run detection
            results = model(frame)
            
            # Draw detection results
            annotated_frame = results[0].plot()
            
            # Add frame counter
            cv2.putText(annotated_frame, f"Frame: {frame_count}/{total_frames}", 
                       (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
            
            # Resize frame if it's too big
            height, width = annotated_frame.shape[:2]
            if width > 1200:
                scale = 1200 / width
                new_width = int(width * scale)
                new_height = int(height * scale)
                annotated_frame = cv2.resize(annotated_frame, (new_width, new_height))
            
            # Display the frame
            cv2.imshow("Video Processing", annotated_frame)
            
            # Exit if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
    
    cap.release()
    cv2.destroyAllWindows()
    print("Video processing completed!")

# %% [markdown]
# ## Key Differences from Advanced Version
#
# ### What makes these examples beginner-friendly:
#
# 1. **Better Error Handling**: Added try-catch blocks and checks for camera/file opening
# 2. **Clear Comments**: Every step is explained with comments
# 3. **Step-by-Step Approach**: Broken down into separate, focused examples
# 4. **Print Statements**: Added informative messages to track progress
# 5. **Simpler Logic**: No complex tracking algorithms, just basic detection
# 6. **Easy Customization**: Clear variables at the top to change settings
#
# ### What the advanced version adds:
# - **Object Tracking**: Uses DeepSORT to track objects across frames with unique IDs
# - **Performance Optimization**: More complex but efficient processing
# - **Advanced Features**: Persistent tracking even when objects are temporarily hidden
#
# ### For Beginners: Start with These Simple Examples
# 1. Run cell 8 first (image detection)
# 2. Then try cell 9 (webcam detection)
# 3. Move to cell 10 (object counting)
# 4. Finally try cell 11 (video processing)
#
# Each example builds on the previous one but remains simple and easy to understand!
